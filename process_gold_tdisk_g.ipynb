# %%
from scipy.io import readsav
import matplotlib.pyplot as plt
import numpy as np
import datetime
from dateutil import parser
import math
# import geopack.geopack as gp
# import ephem
# from ai import cs
import os
import netCDF4 as nc
from apexpy import Apex

# %%
folder = '/Volumes/My Passport/data/GOLD/tdisk/'

# %%
filelist = []

for root, dirs, files in os.walk(folder):
    for file in files:
        #append the file name to the list
        if '._' not in file and '.D' not in file:
            filelist.append(os.path.join(root,file))
filelist.sort()

# %%
ds = nc.Dataset(filelist[0])
for var in ds.variables.values():
    print(var)
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 mask_wavelength(nmask)
#     FORMAT: F8.3
#     VALIDMIN: 130.0
#     DEPEND_0: nmask
#     FIELDNAM: Wavelength grid associated with mask arrays.
#     VAR_TYPE: support data
#     FILLVAL: nan
#     VALIDMAX: 170.0
#     CATDESC: Wavelength grid associated with mask arrays.
# unlimited dimensions:
# current shape = (4001,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 effective_altitude(nscans, nlats, nlons)
#     FORMAT: F10.3
#     DEPEND_1: nlats
#     FIELDNAM: Retrieved Temperature Effective Altitude
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: TDISK Effective Altitude
#     DEPEND_2: nlons
#     UNITS: km
#     VAR_TYPE: data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Retrieved Temperature Effective Altitude
#     VALIDMAX: 1000.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# |S1 lookup_table(nscans, max_string_len)
#     FORMAT: A
#     FILLVAL: *
#     FIELDNAM: Lookup table used to derive neutral temperature
#     CATDESC: Lookup table used to derive neutral temperature
#     VAR_TYPE: metadata
# unlimited dimensions: nscans
# current shape = (68, 50)
# filling on, default _FillValue of  used
# <class 'netCDF4._netCDF4.Variable'>
# float32 tdisk_unc_ran(nscans, nlats, nlons)
#     FORMAT: F10.3
#     DEPEND_1: nlats
#     FIELDNAM: Retrieved Temperature Random Uncertainty
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: TDISK Random Uncertainty
#     DEPEND_2: nlons
#     UNITS: K
#     VAR_TYPE: support_data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Retrieved Temperature Random Uncertainty
#     VALIDMAX: 10000.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 wavelength_stretch(nscans, nlats, nlons)
#     FORMAT: F10.3
#     DEPEND_1: nlats
#     FIELDNAM: Retrieved Temperature Wavelength Stretch
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: TDISK Wavelength Stretch
#     DEPEND_2: nlons
#     UNITS: angstrom
#     VAR_TYPE: data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Retrieved Temperature Wavelength Stretch
#     VALIDMAX: 10.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# |S1 channel(nscans, max_string_len)
#     FORMAT: A1
#     FILLVAL: *
#     FIELDNAM: Channel
#     DEPEND_0: nscans
#     CATDESC: Channel identifier ("A" or "B")
#     VAR_TYPE: metadata
# unlimited dimensions: nscans
# current shape = (68, 50)
# filling on, default _FillValue of  used
# <class 'netCDF4._netCDF4.Variable'>
# float32 latitude(nlats, nlons)
#     FORMAT: F7.2
#     FIELDNAM: Latitude
#     DEPEND_0: nscans
#     VALIDMIN: -90.0
#     VAR_TYPE: support_data
#     LABLAXIS: Latitude
#     UNITS: deg
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Latitude
#     VALIDMAX: 90.0
# unlimited dimensions:
# current shape = (52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 dqi(nscans)
#     FORMAT: I7
#     FIELDNAM: Data Quality Indicator
#     DEPEND_0: nscans
#     VALIDMIN: 0
#     VAR_TYPE: support_data
#     UNITS:
#     FILLVAL: -999999999
#     VALIDMAX: 2147483647
#     CATDESC: File-level Data Quality Indicator. 0 indicates good data. See documentation for list of other values
# unlimited dimensions: nscans
# current shape = (68,)
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# |S1 scan_start_time(nscans, max_string_len)
#     FORMAT: A
#     TIME_BASE: J2000
#     FIELDNAM: Scan Start Time
#     LABLAXIS: time_utc
#     VAR_TYPE: support_data
#     UNITS: s
#     FILLVAL: *
#     CATDESC: Time at beginning of scan (ISO 8601 formatted)
# unlimited dimensions: nscans
# current shape = (68, 50)
# filling on, default _FillValue of  used
# <class 'netCDF4._netCDF4.Variable'>
# float32 solar_zenith_angle(nscans, nlats, nlons)
#     FORMAT: F7.2
#     DEPEND_1: nlats
#     FIELDNAM: Solar Zenith Angle
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: SZA
#     DEPEND_2: nlons
#     UNITS: deg
#     VAR_TYPE: data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Solar Zenith Angle
#     VALIDMAX: 180.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 tdisk_unc_sys(nscans, nlats, nlons)
#     FORMAT: F10.3
#     DEPEND_1: nlats
#     FIELDNAM: Retrieved Temperature Systematic Uncertainty
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: TDISK Systematic Uncertainty
#     DEPEND_2: nlons
#     UNITS: K
#     VAR_TYPE: support_data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Retrieved Temperature Systematic Uncertainty
#     VALIDMAX: 10000.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 tdisk(nscans, nlats, nlons)
#     FORMAT: F10.3
#     DEPEND_1: nlats
#     FIELDNAM: TDISK
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: Retrieved Temperature
#     DEPEND_2: nlons
#     UNITS: K
#     VAR_TYPE: data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Disk neutral temperature
#     VALIDMAX: 10000.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# |S1 time_utc(nscans, nlats, nlons, max_string_len)
#     FORMAT: A
#     TIME_BASE: J2000
#     FIELDNAM: Universal Time
#     LABLAXIS: time_utc
#     VAR_TYPE: support_data
#     UNITS: s
#     FILLVAL: *
#     CATDESC: ISO 8601 formatted UTC timestamp
# unlimited dimensions: nscans
# current shape = (68, 52, 46, 50)
# filling on, default _FillValue of  used
# <class 'netCDF4._netCDF4.Variable'>
# float32 background(nscans, nlats, nlons)
#     FORMAT: F10.3
#     DEPEND_1: nlats
#     FIELDNAM: Retrieved Temperature Background
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: TDISK Background
#     DEPEND_2: nlons
#     VAR_TYPE: data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Retrieved Temperature Background
#     VALIDMAX: 1000.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 wavelength_shift(nscans, nlats, nlons)
#     FORMAT: F10.3
#     DEPEND_1: nlats
#     FIELDNAM: Retrieved Temperature Wavelength Shift
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: TDISK Wavelength Shift
#     DEPEND_2: nlons
#     UNITS: angstrom
#     VAR_TYPE: data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Retrieved Temperature Wavelength Shift
#     VALIDMAX: 10.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 longitude(nlats, nlons)
#     FORMAT: F7.2
#     FIELDNAM: Longitude
#     DEPEND_0: nscans
#     VALIDMIN: -180.0
#     VAR_TYPE: data
#     LABLAXIS: Longitude
#     UNITS: deg
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Longitude
#     VALIDMAX: 180.0
# unlimited dimensions:
# current shape = (52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 vibrational_populations(nscans, nlats, nlons, npop)
#     FORMAT: F10.3
#     DEPEND_1: nlats
#     FIELDNAM: Retrieved Temperature Vibrational Populations
#     DEPEND_0: nscans
#     DEPEND_3: npop
#     VALIDMIN: 0.0
#     DEPEND_2: nlons
#     VAR_TYPE: data
#     FILLVAL: nan
#     CATDESC: Retrieved Temperature  Vibrational Populations
#     VALIDMAX: 1.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46, 7)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# |S1 input_l1c_file(nscans, max_string_len)
#     FORMAT: A
#     FILLVAL: *
#     FIELDNAM: Input L1C File
#     DEPEND_0: nscans
#     CATDESC: Corresponding Input L1C File
#     VAR_TYPE: metadata
# unlimited dimensions: nscans
# current shape = (68, 50)
# filling on, default _FillValue of  used
# <class 'netCDF4._netCDF4.Variable'>
# float32 emission_angle(nscans, nlats, nlons)
#     FORMAT: F7.2
#     DEPEND_1: nlats
#     FIELDNAM: Emission Angle
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: Emission Angle
#     DEPEND_2: nlons
#     UNITS: deg
#     VAR_TYPE: data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Emission Angle
#     VALIDMAX: 90.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 tdisk_dqi(nscans, nlats, nlons)
#     FORMAT: I7
#     DEPEND_1: nlats
#     FIELDNAM: Retrieved Temperature Data Quality Indicator
#     DEPEND_0: nscans
#     VALIDMIN: 0
#     LABLAXIS: TDISK DQI
#     DEPEND_2: nlons
#     UNITS:
#     VAR_TYPE: support_data
#     FILLVAL: -999999999
#     DISPLAY_TYPE: image
#     CATDESC: Retrieved Temperature Data Quality Indicator. 0 indicates good data. See documentation for list of other values
#     VALIDMAX: 2147483647
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 mask_n2_lbh(nmask)
#     FORMAT: I1
#     VALIDMIN: 0
#     DEPEND_0: nmask
#     FIELDNAM: Wavelength mask used for fitting N2 LBH.
#     VAR_TYPE: support data
#     FILLVAL: -999999999
#     VALIDMAX: 1
#     CATDESC: Wavelength mask used for fitting N2 LBH.
# unlimited dimensions:
# current shape = (4001,)
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# |S1 scan_stop_time(nscans, max_string_len)
#     FORMAT: A
#     TIME_BASE: J2000
#     FIELDNAM: Scan Stop Time
#     LABLAXIS: time_utc
#     VAR_TYPE: support_data
#     UNITS: s
#     FILLVAL: *
#     CATDESC: Time at end of scan (ISO 8601 formatted)
# unlimited dimensions: nscans
# current shape = (68, 50)
# filling on, default _FillValue of  used
# <class 'netCDF4._netCDF4.Variable'>
# float32 tdisk_unc_mod(nscans, nlats, nlons)
#     FORMAT: F10.3
#     DEPEND_1: nlats
#     FIELDNAM: Retrieved Temperature Model Uncertainty
#     DEPEND_0: nscans
#     VALIDMIN: 0.0
#     LABLAXIS: TDISK Model Uncertainty
#     DEPEND_2: nlons
#     UNITS: K
#     VAR_TYPE: support_data
#     FILLVAL: nan
#     DISPLAY_TYPE: image
#     CATDESC: Retrieved Temperature Model Uncertainty
#     VALIDMAX: 10000.0
# unlimited dimensions: nscans
# current shape = (68, 52, 46)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# |S1 hemisphere(nscans, max_string_len)
#     FORMAT: A1
#     FILLVAL: *
#     FIELDNAM: Hemisphere
#     DEPEND_0: nscans
#     CATDESC: Hemisphere observed ("N" or "S")
#     VAR_TYPE: metadata
# unlimited dimensions: nscans
# current shape = (68, 50)
# filling on, default _FillValue of  used

# %%
td=ds['tdisk']
lat=ds['latitude']
lon=ds['longitude']
st_time=ds['scan_start_time']
en_time=ds['scan_stop_time']
ch=ds['channel']
dqi=ds['dqi']
td_dqi=ds['tdisk_dqi']

# %%
for i in range(td.shape[2]):
    plt.scatter(lon[:], lat[:], c=td[i,:,:])

# %%
# Deal with string in ncdf
starttime=[]
endtime=[]
channel=[]
for i in range(st_time.shape[0]):
    index=st_time[i].mask
    starttime.append(st_time[i, ~index].tobytes().decode("utf-8"))
    endtime.append(en_time[i, ~index].tobytes().decode("utf-8"))
    index=ch[i].mask
    channel.append(ch[i, ~index].tobytes().decode("utf-8"))

# %%
def geo2mag_sphere_apex(lat,lon,h,t):
    
    # GEOPACK is based on a centered dipole coordinate.
    t1 = parser.parse(t)
    
    A = Apex(date=t1)
    mlat, mlon = A.convert(lat, lon, 'geo', 'apex', height=0)
    mlt = A.mlon2mlt(mlon, t1)
    return mlat, mlon, mlt

# %%
def mag2geo_sphere_apex(mlat,mlon,h,t):
    
    # GEOPACK is based on a centered dipole coordinate.
    t1 = parser.parse(t)
    
    A = Apex(date=t1)
    lat, lon = A.convert(mlat, mlon, 'apex', 'geo', height=0)
    mlt = A.mlon2mlt(mlon, t1)
    return lat, lon, mlt

# %%
# test apex

lateq=np.zeros([360,])
loneq=np.zeros([360,])

for j in range(-90,90,10):
    for i in range(360): # lat.shape[0]
        lateq[i], loneq[i], _=mag2geo_sphere_apex(j,i,0,starttime[0][:-1])
    
    plt.scatter(loneq,lateq)

# %%
# test apex mlt, compared with aacgm
mlat, mlon, mlt=geo2mag_sphere_apex(40,40,0,starttime[0][:-1])
print(starttime[0][:-1], mlat,mlon,mlt)
# Out:
# 2019-01-01T06:10:31 35.45655059814453 112.56793975830078 8.894235738118489

# %%
td_rebin_lt=np.empty((180,120),dtype=object)
td_rebin_lon=np.empty((180,120),dtype=object)

for i in range(180):
    for j in range(120):
        td_rebin_lt[i,j]=[]
        td_rebin_lon[i,j]=[]

# %%
for t, f in enumerate(filelist):
    ds = nc.Dataset(f)
    print(f, datetime.datetime.now())
    td=ds['tdisk']
    lat=ds['latitude']
    lon=ds['longitude']
    st_time=ds['scan_start_time']
    en_time=ds['scan_stop_time']
    ch=ds['channel']
    dqi=ds['dqi']
    td_dqi=ds['tdisk_dqi']
    starttime=[]
    endtime=[]
    channel=[]
    for i in range(st_time.shape[0]):
        index=st_time[i].mask
        starttime.append(st_time[i, ~index].tobytes().decode("utf-8"))
        endtime.append(en_time[i, ~index].tobytes().decode("utf-8"))
        index=ch[i].mask
        channel.append(ch[i, ~index].tobytes().decode("utf-8"))
    
    for i in range(td.shape[0]):
        if dqi[i]==0:
            for j in range(td.shape[1]):
                for k in range(td.shape[2]): 
                    if not np.isnan(td[i,j,k]) and td_dqi[i,j,k]==0 and channel[i]=='CHA':
                        glat=lat[j,k]
                        glon=lon[j,k]
                        dtime=parser.parse(starttime[i][0:-1])
                        doy=dtime.timetuple().tm_yday
                        lt=glon/15+dtime.hour+dtime.minute/60
                        if lt>24: lt=lt-24
        #                 month=int(starttime[i][5:7])-1
                        x=int(glat+90)
                        y=int(lt*15/3)
                        td_rebin_lt[x,y].append((dtime,float(td[i,j,k])))
                        x=int(glat+90)
                        y=int(glon/3+60)
                        td_rebin_lon[x,y].append((dtime,float(td[i,j,k])))
    if t % 100 ==0:
        np.save('td_rebin_lt.npy', td_rebin_lt)
        np.save('td_rebin_lon.npy', td_rebin_lon)
np.save('td_rebin_lt.npy', td_rebin_lt)
np.save('td_rebin_lon.npy', td_rebin_lon)
# Out:
# /Volumes/My Passport/data/GOLD/tdisk/2019/001/GOLD_L2_TDISK_2019_001_v03_r01_c01.nc 2023-09-05 16:56:35.041368
# /Volumes/My Passport/data/GOLD/tdisk/2019/002/GOLD_L2_TDISK_2019_002_v03_r01_c01.nc 2023-09-05 16:59:10.502890
# /Volumes/My Passport/data/GOLD/tdisk/2019/003/GOLD_L2_TDISK_2019_003_v03_r01_c01.nc 2023-09-05 17:02:10.937759
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 39
#      37                     x=int(glat+90)
#      38                     y=int(glon/3+60)
# ---> 39                     td_rebin_lon[x,y].append((dtime,float(td[i,j,k])))
#      40 if t % 100 ==0:
#      41     np.save('td_rebin_lt.npy', td_rebin_lt)
#
# File src/netCDF4/_netCDF4.pyx:4997, in netCDF4._netCDF4.Variable.__getitem__()
#
# File src/netCDF4/_netCDF4.pyx:5206, in netCDF4._netCDF4.Variable._toma()
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/core/_methods.py:55, in _any(a, axis, dtype, out, keepdims, where)
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      52           initial=_NoValue, where=True):
#      53     return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# ---> 55 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      56     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      57     if where is True:
#      58         return umr_any(a, axis, dtype, out, keepdims)
#
# KeyboardInterrupt:

# %%
k=0
for i in range(180):
    for j in range(120):
        if len(td_rebin_mlt[i,j])>0:
            k=k+1
print(k/120/180)
# Out:
# 0.38324074074074077
